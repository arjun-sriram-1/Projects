# %%
import joblib

# %%
model = joblib.load('fraud_model.pkl')

# %%
prediction = model.predict([[7000, 8000, 1000]])
print("Prediction:", "Fraud" if prediction[0] == 1 else "Not Fraud")
# Out:
# Prediction: Fraud
# c:\Users\sriram\anaconda3\envs\tensor\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
